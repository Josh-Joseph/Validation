# %%
import runner

# %load_ext disable_autoscroll
# Out:
# autoscrolling long output is disabled

# %%
runner.test()
# Out:
# (<dataset.RandomPolynomial object at 0x00000000099773C8>, Spec[<class 'models.NearestNeighbor'>( (), {} )], <validation.SumOfDistanceObjective object at 0x00000000099774A8>, 2, 10, 0.1, None) : 172.675900614
# (<dataset.RandomPolynomial object at 0x00000000099773C8>, Spec[<class 'models.NearestNeighbor'>( (), {} )], <validation.SumOfDistanceObjective object at 0x00000000099774A8>, 2, 10, 0.5, None) : 24.7374261367
# (<dataset.RandomPolynomial object at 0x00000000099773C8>, Spec[<class 'models.NearestNeighbor'>( (), {} )], <validation.SumOfDistanceObjective object at 0x00000000099774A8>, 2, 10, 0.7, None) : 71.2562534464
# (<dataset.RandomPolynomial object at 0x00000000099773C8>, Spec[<class 'models.NearestNeighbor'>( (), {} )], <validation.SumOfDistanceObjective object at 0x00000000099774A8>, 2, 20, 0.1, None) : 247.320793232
# ...
